# %%
import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt
import yaml

from gammapy.datasets import MapDataset, Datasets, FluxPointsDataset
from gammapy.maps import Map
from gammapy.makers import FoVBackgroundMaker
from gammapy.catalog import SourceCatalogHGPS, SourceCatalogGammaCat, SourceCatalog4FGL

# %%
hessera='hess2'
muoneff_flag= True
edisp = True

name = f'20220702_{hessera}_muoneff{muoneff_flag}_edisp{edisp}.fits'

# %%
hess= MapDataset.read(name)
hess.mask_safe = Map.from_geom(geom=hess.counts.geom, data=np.ones_like(hess.counts.data).astype(bool))   
hess.mask_safe &= hess.counts.geom.region_mask(f"galactic;circle(0, 0, 3)")

# %%
(hess.counts-hess.background).sum_over_axes().smooth(2).plot(add_cbar=True)
# Out:
# <WCSAxesSubplot:xlabel='Galactic Longitude', ylabel='Galactic Latitude'>

# %%
HGPS, FGL4 = SourceCatalogHGPS(), SourceCatalog4FGL()

# %%
catalog = HGPS
mask1 = np.abs(catalog.table['GLAT']) < 2.6
mask2 = (catalog.table['GLON'] < 2.6) + (catalog.table['GLON'] > 357.4)
mask = mask1 & mask2

HGPS_models = catalog[mask].to_models()

# %%
from gammapy.modeling.models import SkyModel, TemplateSpatialModel, PowerLawNormSpectralModel

diff_map = Map.read('/home/saturn/caph/mppi043h/diffusiontemplate/cont_pcut_v3.fits')
#diff_map.geom.axes['energy'].name = 'energy_true'

diff= SkyModel(spectral_model=PowerLawNormSpectralModel(),
               spatial_model=TemplateSpatialModel(diff_map, normalize=False),
               name='diff-emission')

# %%
initial_model_hess = HGPS_models
hess.models = initial_model_hess.copy()
hess.models += diff
hess = FoVBackgroundMaker().make_default_fov_background_model(dataset=hess)

# %%
dataset = hess
dataset.mask_fit = Map.from_geom(geom=dataset.counts.geom, data=np.ones_like(dataset.counts.data).astype(bool))   
dataset.mask_fit &= ~dataset.counts.geom.region_mask(f"galactic;circle(358.71, -0.64, 0.7)")

# %%
frozen_sources= ['HESS J1745-303', 'HESS J1746-308']

for s in hess.models:
    if s.name in frozen_sources:
        s.parameters.freeze_all()

# %%
print(hess.models)
# Out:
# DatasetModels
#
# Component 0: SkyModel
#
#   Name                      : HESS J1741-302
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :      2.300   +/-    0.20
#     amplitude               :   2.10e-13   +/- 4.0e-14 1 / (cm2 s TeV)
#     reference    (frozen)   :      1.000       TeV
#     lon_0                   :    358.277   +/-    0.00 deg
#     lat_0                   :      0.049   +/-    0.00 deg
#
# Component 1: SkyModel
#
#   Name                      : HESS J1745-290
#   Datasets names            : None
#   Spectral model type       : ExpCutoffPowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :      2.140   +/-    0.02
#     amplitude               :   2.55e-12   +/- 4.0e-14 1 / (cm2 s TeV)
#     reference    (frozen)   :      1.000       TeV
#     lambda_                 :      0.093   +/-    0.02 1 / TeV
#     alpha        (frozen)   :      1.000
#     lon_0                   :    359.945   +/-    0.00 deg
#     lat_0                   :     -0.044   +/-    0.00 deg
#
# Component 2: SkyModel
#
#   Name                      : HESS J1745-303
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index        (frozen)   :      2.567
#     amplitude    (frozen)   :   2.47e-12       1 / (cm2 s TeV)
#     reference    (frozen)   :      0.867       TeV
#     lon_0        (frozen)   :    358.645       deg
#     lat_0        (frozen)   :     -0.564       deg
#     sigma        (frozen)   :      0.179       deg
#     e            (frozen)   :      0.000
#     phi          (frozen)   :      0.000       deg
#
# Component 3: SkyModel
#
#   Name                      : HESS J1746-285
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :      2.170   +/-    0.24
#     amplitude               :   1.80e-13   +/- 4.6e-14 1 / (cm2 s TeV)
#     reference    (frozen)   :      1.000       TeV
#     lon_0                   :      0.140   +/-    0.00 deg
#     lat_0                   :     -0.114   +/-    0.00 deg
#
# Component 4: SkyModel
#
#   Name                      : HESS J1746-308
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : GaussianSpatialModel
#   Temporal model type       :
#   Parameters:
#     index        (frozen)   :      3.271
#     amplitude    (frozen)   :   7.21e-12       1 / (cm2 s TeV)
#     reference    (frozen)   :      0.488       TeV
#     lon_0        (frozen)   :    358.448       deg
#     lat_0        (frozen)   :     -1.114       deg
#     sigma        (frozen)   :      0.162       deg
#     e            (frozen)   :      0.000
#     phi          (frozen)   :      0.000       deg
#
# Component 5: SkyModel
#
#   Name                      : HESS J1747-281
#   Datasets names            : None
#   Spectral model type       : PowerLawSpectralModel
#   Spatial  model type       : PointSpatialModel
#   Temporal model type       :
#   Parameters:
#     index                   :      2.400   +/-    0.11
#     amplitude               :   8.38e-13   +/- 1.3e-13 1 / (cm2 s TeV)
#     reference    (frozen)   :      1.000       TeV
#     lon_0                   :      0.872   +/-    0.00 deg
#     lat_0                   :      0.076   +/-    0.00 deg
#
# Component 6: SkyModel
#
#   Name                      : diff-emission
#   Datasets names            : None
#   Spectral model type       : PowerLawNormSpectralModel
#   Spatial  model type       : TemplateSpatialModel
#   Temporal model type       :
#   Parameters:
#     norm                    :      1.000   +/-    0.00
#     tilt         (frozen)   :      0.000
#     reference    (frozen)   :      1.000       TeV
#
# Component 7: FoVBackgroundModel
#
#   Name                      : o4JrBJfh-bkg
#   Datasets names            : ['o4JrBJfh']
#   Spectral model type       : PowerLawNormSpectralModel
#   Parameters:
#     norm                    :      1.000   +/-    0.00
#     tilt         (frozen)   :      0.000
#     reference    (frozen)   :      1.000       TeV

# %%
from gammapy.modeling import Fit

result0= Fit().run(datasets=[hess])
print(result0)
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (33.02337301, 0.04908089)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (33.02337301, 0.04908089)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (323.5302769, 0.04908089)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (323.5302769, 0.04908089)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.59552416, 0.04908089)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (353.59552416, 0.04908089)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (34.69143331, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (34.69143331, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (325.1983372, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (325.1983372, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.41954006, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (3.41954006, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.47023045, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (356.47023045, -0.04391105)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (214.99020386, 79.50621625)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (214.99020386, 79.50621625)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (288.02441406, 83.16897108)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (288.02441406, 83.16897108)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (299.31138684, -28.0580406)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (299.31138684, -28.0580406)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (29.3467687, -77.32884668)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (29.3467687, -77.32884668)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (177.76881409, -65.56087555)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (177.76881409, -65.56087555)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (42.11816406, -79.73324792)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (42.11816406, -79.73324792)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (251.59925017, -73.54730472)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (251.59925017, -73.54730472)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (19.015404, -21.13467052)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (19.015404, -21.13467052)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (267.61026764, -11.3539626)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (267.61026764, -11.3539626)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (247.11450195, 67.379649)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (247.11450195, 67.379649)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (93.21013785, 76.19642188)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (93.21013785, 76.19642188)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (219.73959369, 83.28913667)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (219.73959369, 83.28913667)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (296.75401688, -58.78433687)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (296.75401688, -58.78433687)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (254.86314392, 89.44398013)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (254.86314392, 89.44398013)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (123.51193339, -54.36792858)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (123.51193339, -54.36792858)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (318.97005372, 29.95280807)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (318.97005372, 29.95280807)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (187.98166466, -87.15513202)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (187.98166466, -87.15513202)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (193.93153381, -32.74246039)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (193.93153381, -32.74246039)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (281.81034076, -81.16823782)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (281.81034076, -81.16823782)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (91.05900515, -50.18378528)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (91.05900515, -50.18378528)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (163.56423378, 60.36443513)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (163.56423378, 60.36443513)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (287.6947403, 89.86425656)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (287.6947403, 89.86425656)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (71.7418148, -89.74191624)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (71.7418148, -89.74191624)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (284.89858934, 23.19583083)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (284.89858934, 23.19583083)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (212.70638752, -23.17339156)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (212.70638752, -23.17339156)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (240.30279541, 72.15938376)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (240.30279541, 72.15938376)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (181.70731941, -83.97143497)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (181.70731941, -83.97143497)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.0140825, -85.42529628)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (354.0140825, -85.42529628)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (164.4923811, 70.49675566)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (164.4923811, 70.49675566)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (63.40504837, -42.18355656)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (63.40504837, -42.18355656)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (73.99643404, -61.63833181)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (73.99643404, -61.63833181)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (103.82815585, 21.67153743)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (103.82815585, 21.67153743)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (139.55205154, -79.08983387)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (139.55205154, -79.08983387)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (125.0338316, -69.49188487)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (125.0338316, -69.49188487)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.69848018, -49.76575624)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (28.69848018, -49.76575624)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (15.94723997, 85.55948839)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (15.94723997, 85.55948839)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (263.79778671, 86.95797284)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (263.79778671, 86.95797284)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (295.17518139, -89.71271845)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (295.17518139, -89.71271845)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (10.280929, -82.50878343)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (10.280929, -82.50878343)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (170.4070416, -81.06150571)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (170.4070416, -81.06150571)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (234.5689308, 52.48130952)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (234.5689308, 52.48130952)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (117.52447689, 72.47796597)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (117.52447689, 72.47796597)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (183.16446699, -15.45201247)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (183.16446699, -15.45201247)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (76.73532088, -89.77588138)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (76.73532088, -89.77588138)> is outside valid IRF map range, using nearest IRF defined within
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 3696
# 	total stat : 505467.10
#
# OptimizeResult
#
# 	backend    : minuit
# 	method     : migrad
# 	success    : True
# 	message    : Optimization terminated successfully.
# 	nfev       : 3696
# 	total stat : 505467.10

# %%
from gammapy.estimators import ExcessMapEstimator

estimator = ExcessMapEstimator(
    correlation_radius="0.2 deg",
    selection_optional=[],
    energy_edges=[0.1, 100] * u.TeV,
)
result = estimator.run(hess)

fig, ax = plt.subplots(1,2, figsize=(15, 3))
result["sqrt_ts"].plot(cmap="coolwarm", add_cbar=True, vmin=-5, vmax=5, ax=ax[0]);
data=result["sqrt_ts"].data.ravel()
ax[1].hist(data, bins=np.linspace(-5,5,30), label=f'mean={np.nanmean(data):.3f}\nstd={np.nanstd(data):.3f}');
plt.legend()
# Out:
# /home/woody/caph/mppi062h/software/anaconda/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/gammapy/maps/wcs/ndmap.py:372: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   im = ax.imshow(data, **kwargs)

# %%
(result["sqrt_ts"]).plot(cmap="coolwarm", add_cbar=True, vmin=-5, vmax=5);
# Out:
# /home/woody/caph/mppi062h/software/anaconda/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)

# %%
from gammapy.estimators import ExcessMapEstimator

estimator = ExcessMapEstimator(
    correlation_radius="0.2 deg",
    selection_optional=[],
    energy_edges=dataset.counts.geom.axes['energy'].edges,
)
result = estimator.run(hess)

result["sqrt_ts"].plot_grid(
    figsize=(18, 18), cmap="coolwarm", add_cbar=True, vmin=-5, vmax=5, ncols=4);

fig, ax = plt.subplots(1,4, figsize=(18, 3))

for i in range(2, 6):
    data=result["sqrt_ts"].data[i].ravel()
    ax[i-2].hist(data, bins=np.linspace(-5,5,30), label=f'mean={np.nanmean(data):.3f}\nstd={np.nanstd(data):.3f}');
    ax[i-2].legend()
# Out:
# /home/woody/caph/mppi062h/software/anaconda/anaconda3/envs/gammapy-0.19/lib/python3.9/site-packages/astropy/visualization/wcsaxes/core.py:211: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   return super().imshow(X, *args, origin=origin, **kwargs)

# %%
from gammapy.estimators import FluxPoints, FluxPointsEstimator

fp_central = FluxPointsEstimator(
    energy_edges=hess.counts.geom.axes['energy'].edges,
    source="HESS J1745-290",
).run([hess])
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within

# %%
x_axis = hess.counts.geom.axes['energy'].center.value
energy_bounds = [0.01, 100] * u.TeV
sed_type = "e2dnde"

for s, fp in zip(['HESS J1745-290'], [fp_central]):
    plt.figure(figsize=(8, 6))

    ax = hess.models[s].spectral_model.plot(
        energy_bounds=energy_bounds, sed_type=sed_type, label="Model")
    hess.models[s].spectral_model.plot_error(ax=ax, energy_bounds=energy_bounds, sed_type=sed_type)
    fp.plot(ax=ax, sed_type=sed_type, label="HESS")
    ax.set_xlim(energy_bounds)
    plt.legend();

    plt.show()

# %%
name = 'fp_'+f'20220702_{hessera}_muoneff{muoneff_flag}_edisp{edisp}.fits'
fp_central.write(name)

# %%
fp_edges = np.concatenate((hess.counts.geom.axes['energy'].edges[:16], [20, 100]*u.TeV))

# %%
fp_central = FluxPointsEstimator(
    energy_edges=fp_edges,
    source="HESS J1745-290",
).run([hess])
# Out:
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (357.40792063, -0.17192051)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (359.94065206, -0.04159609)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.64483643, -0.56421703)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.1564469, -0.10993924)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (358.44821167, -1.11440229)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0.86704505, 0.06883464)> is outside valid IRF map range, using nearest IRF defined within
# Position <SkyCoord (Galactic): (l, b) in deg
#     (0., 0.)> is outside valid IRF map range, using nearest IRF defined within

# %%
x_axis = hess.counts.geom.axes['energy'].center.value
energy_bounds = [0.01, 100] * u.TeV
sed_type = "e2dnde"

for s, fp in zip(['HESS J1745-290'], [fp_central]):
    plt.figure(figsize=(8, 6))

    ax = hess.models[s].spectral_model.plot(
        energy_bounds=energy_bounds, sed_type=sed_type, label="Model")
    hess.models[s].spectral_model.plot_error(ax=ax, energy_bounds=energy_bounds, sed_type=sed_type)
    fp.plot(ax=ax, sed_type=sed_type, label="HESS")
    ax.set_xlim(energy_bounds)
    plt.legend();

    plt.show()

# %%
name = 'fp_'+f'20220702_{hessera}_muoneff{muoneff_flag}_edisp{edisp}.fits'
fp_central.write(name)
